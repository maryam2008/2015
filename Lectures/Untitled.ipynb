# %%
import pandas as pd
just_practice = pd.read_csv('//wnpcdapcpx01/Data/BPM/FTP/WorkforcePlanning/TempContractor/Contractors_Accrual.csv',index_col=0)
columns_a= just_practice[['City','Commit ID','Assignment ID','Cost Code']]
columns_b = just_practice[just_pratice.city=='London'].head()
columns_b.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-5d6ed64d136b> in <module>
#       2 just_practice = pd.read_csv('//wnpcdapcpx01/Data/BPM/FTP/WorkforcePlanning/TempContractor/Contractors_Accrual.csv',index_col=0)
#       3 columns_a= just_practice[['City','Commit ID','Assignment ID','Cost Code']]
# ----> 4 columns_b = just_practice[just_pratice.city=='London'].head()
#       5 columns_b.head()
#
# NameError: name 'just_pratice' is not defined

# %%
import numpy as np

# %%
just_practice.head()
# Out:
#                            Temporary Worker First Name Commit ID  \
# Temporary Worker Last Name
# Radden                                          Warren   ADCZ2MY
# Kelly                                           Robert   ADCX4QS
# Noll                                           Richard   ADCDXJZ
# Noll                                           Richard   ADCDXJZ
# Brouillard                                      Edward   ADCDXF2
#
#                             Assignment ID  Cost Code Hiring Manager Last Name  \
# Temporary Worker Last Name
# Radden                               1003    8121029                Scribbins
# Kelly                                1088    8262073                  Baillie
# Noll                                 1132     142500                 McMenamy
# Noll                                 1132     142500                 McMenamy
# Brouillard                           1250     142500                 McMenamy
#
# ...

# %%
columns_a= just_practice[['City','Commit ID','Assignment ID','Cost Code']]
columns_b = Just_practice[just_practice.city=='London']
columns_b.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-42e78ef0ac6f> in <module>
#       1 columns_a= just_practice[['City','Commit ID','Assignment ID','Cost Code']]
# ----> 2 columns_b = Just_practice[just_practice.city=='London']
#       3 columns_b.head()
#
# NameError: name 'Just_practice' is not defined
